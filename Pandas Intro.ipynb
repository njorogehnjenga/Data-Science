# %% [markdown]
# # INTRO TO PANDAS

# %%
import pandas as pd
DF1= {
    "Customer ID":[1,2,3,4,5,6],
    "Product":['Oven','Oven','Oven','Telly','Telly','Telly']
}
Df1= pd.DataFrame(DF1)
Df1
# Out:
#    Customer ID Product
# 0            1    Oven
# 1            2    Oven
# 2            3    Oven
# 3            4   Telly
# 4            5   Telly
# 5            6   Telly

# %%
countries={'Countryname':['Kenya','Tanzania','United Kingdom'], 'Population':['45000000','262000000','34000000']}

# %%
import pandas as pd
counties={'Name':['Nrb','Msa','Kis'],'Size':['2000','1000','10000']}
counties_df= pd.DataFrame(counties)
counties_df
# Out:
#   Name   Size
# 0  Nrb   2000
# 1  Msa   1000
# 2  Kis  10000

# %%
my_dict={'country_name':['United States','Australia','Japan','India','Russia','Monaco','Egypt'],
         'drives_right':[True, False, False, False, True, True, True], 'cars_per_cap':[809,731,588,18,200,70,45]}

# %%
My_dict= pd.DataFrame(my_dict)
My_dict
# Out:
#     country_name  drives_right  cars_per_cap
# 0  United States          True           809
# 1      Australia         False           731
# 2          Japan         False           588
# 3          India         False            18
# 4         Russia          True           200
# 5         Monaco          True            70
# 6          Egypt          True            45

# %%
train =pd.read_csv('train.csv')
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
train.tail()
#tail brings the last five values
#head brings the first 10 values
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
train.describe()
#describe gives
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train.describe(include=['object'])
# Out:
#                               Name   Sex Ticket Cabin Embarked
# count                          891   891    891   204      889
# unique                         891     2    681   147        3
# top     Rommetvedt, Mr. Knud Paust  male   1601    G6        S
# freq                             1   577      7     4      644

# %% [markdown]
# ### .replace to replace columns(old:new)

# %%
train.Sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
train.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
train.fillna()

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train.shape
#rows and columns
# Out:
# (891, 12)

# %%
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#rename is used to rename columns
#df.rename(columns={old:new}, inplace=True)
#df=df.rename(columns={old:new})

train.rename(columns={'Sex':'Gender'}, inplace=True)
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train= train.rename(columns={'Fare':'Price'})
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train.isnull().any()
#true has missing values, false does not
#sum gives number of missing values
# Out:
# 3

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Gender           0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Price            0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## Indexing and selecting data
# 1. Use square brackets
# 2. loc and iloc

# %%
train['Gender']
type(train['Gender'])
train['Gender']
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Gender, Length: 891, dtype: object

# %%
train[['Gender']]
type(train[['Gender']])
train[['Gender']]
# Out:
#      Gender
# 0      male
# 1    female
# 2    female
# 3    female
# 4      male
# ..      ...
# 886    male
# 887  female
# 888  female
# 889    male
# 890    male
#
# [891 rows x 1 columns]

# %%
train[['Name','Gender','Age','Survived']]
# Out:
#                                                   Name  Gender   Age  Survived
# 0                              Braund, Mr. Owen Harris    male  22.0         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0         1
# 2                               Heikkinen, Miss. Laina  female  26.0         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0         1
# 4                             Allen, Mr. William Henry    male  35.0         0
# ..                                                 ...     ...   ...       ...
# 886                              Montvila, Rev. Juozas    male  27.0         0
# 887                       Graham, Miss. Margaret Edith  female  19.0         1
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN         0
# 889                              Behr, Mr. Karl Howell    male  26.0         1
# 890                                Dooley, Mr. Patrick    male  32.0         0
#
# [891 rows x 4 columns]

# %%
train[['Age']].mean()
# Out:
# Age    29.699118
# dtype: float64

# %%
train['Age'].min()
# Out:
# 0.42

# %%
train['Age'].max()
# Out:
# 80.0

# %%
train[5:71]
# Out:
#     PassengerId  Survived  Pclass  \
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# ..          ...       ...     ...
# 66           67         1       2
# 67           68         0       3
# 68           69         1       3
# 69           70         0       3
# 70           71         0       2
#
#                                                  Name  Gender   Age  SibSp  \
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                ...     ...   ...    ...
# ...

# %%
#loc is label based- looks for the name
#iloc is integer/index based- counts

# %%
import pandas as pd

# %%
hse= pd.read_csv('HousePrices.csv')
hse
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
head= hse.head(20)
head
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0    1          60       RL         65.0     8450   Pave   NaN      Reg
# 1    2          20       RL         80.0     9600   Pave   NaN      Reg
# 2    3          60       RL         68.0    11250   Pave   NaN      IR1
# 3    4          70       RL         60.0     9550   Pave   NaN      IR1
# 4    5          60       RL         84.0    14260   Pave   NaN      IR1
# 5    6          50       RL         85.0    14115   Pave   NaN      IR1
# 6    7          20       RL         75.0    10084   Pave   NaN      Reg
# 7    8          60       RL          NaN    10382   Pave   NaN      IR1
# 8    9          50       RM         51.0     6120   Pave   NaN      Reg
# 9   10         190       RL         50.0     7420   Pave   NaN      Reg
# 10  11          20       RL         70.0    11200   Pave   NaN      Reg
# 11  12          60       RL         85.0    11924   Pave   NaN      IR1
# ...

# %%
tail=hse.tail(20)
tail
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1440  1441          70       RL         79.0    11526   Pave   NaN      IR1
# 1441  1442         120       RM          NaN     4426   Pave   NaN      Reg
# 1442  1443          60       FV         85.0    11003   Pave   NaN      Reg
# 1443  1444          30       RL          NaN     8854   Pave   NaN      Reg
# 1444  1445          20       RL         63.0     8500   Pave   NaN      Reg
# 1445  1446          85       RL         70.0     8400   Pave   NaN      Reg
# 1446  1447          20       RL          NaN    26142   Pave   NaN      IR1
# 1447  1448          60       RL         80.0    10000   Pave   NaN      Reg
# 1448  1449          50       RL         70.0    11767   Pave   NaN      Reg
# 1449  1450         180       RM         21.0     1533   Pave   NaN      Reg
# 1450  1451          90       RL         60.0     9000   Pave   NaN      Reg
# ...

# %%
print(hse.head(20)) + print(hse.tail(20))
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0    1          60       RL         65.0     8450   Pave   NaN      Reg
# 1    2          20       RL         80.0     9600   Pave   NaN      Reg
# 2    3          60       RL         68.0    11250   Pave   NaN      IR1
# 3    4          70       RL         60.0     9550   Pave   NaN      IR1
# 4    5          60       RL         84.0    14260   Pave   NaN      IR1
# 5    6          50       RL         85.0    14115   Pave   NaN      IR1
# 6    7          20       RL         75.0    10084   Pave   NaN      Reg
# 7    8          60       RL          NaN    10382   Pave   NaN      IR1
# 8    9          50       RM         51.0     6120   Pave   NaN      Reg
# 9   10         190       RL         50.0     7420   Pave   NaN      Reg
# 10  11          20       RL         70.0    11200   Pave   NaN      Reg
# 11  12          60       RL         85.0    11924   Pave   NaN      IR1
# ...

# %%
con= pd.concat([head,tail])
con
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 5        6          50       RL         85.0    14115   Pave   NaN      IR1
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# 8        9          50       RM         51.0     6120   Pave   NaN      Reg
# 9       10         190       RL         50.0     7420   Pave   NaN      Reg
# 10      11          20       RL         70.0    11200   Pave   NaN      Reg
# ...

# %%
con2= pd.concat([hse.head(20),hse.tail(20)])
con2
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 5        6          50       RL         85.0    14115   Pave   NaN      IR1
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# 8        9          50       RM         51.0     6120   Pave   NaN      Reg
# 9       10         190       RL         50.0     7420   Pave   NaN      Reg
# 10      11          20       RL         70.0    11200   Pave   NaN      Reg
# ...

# %%
hse.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
hse= hse.rename(columns={'MoSold':'Month_Sold','YrSold':'Year_Sold'})
hse
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
#concat is used to join two different things

# %%
r5= hse[5:6]
r10= hse[10:11]
r15= hse[15:16]
rall= pd.concat([r5,r10,r15])
rall
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 5    6          50       RL         85.0    14115   Pave   NaN      IR1
# 10  11          20       RL         70.0    11200   Pave   NaN      Reg
# 15  16          45       RM         51.0     6120   Pave   NaN      Reg
#
#    LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 5          Lvl    AllPub  ...        0    NaN  MnPrv        Shed     700
# 10         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 15         Lvl    AllPub  ...        0    NaN  GdPrv         NaN       0
#
#    Month_Sold Year_Sold  SaleType  SaleCondition  SalePrice
# 5          10      2009        WD         Normal     143000
# 10          2      2008        WD         Normal     129500
# 15          7      2007        WD         Normal     132000
#
# [3 rows x 81 columns]

# %% [markdown]
# # loc and iloc

# %%
hse.loc[[1]]
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 1   2007        WD         Normal     181500
#
# [1 rows x 81 columns]

# %%
hse.loc[[5,10,15]]
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 5    6          50       RL         85.0    14115   Pave   NaN      IR1
# 10  11          20       RL         70.0    11200   Pave   NaN      Reg
# 15  16          45       RM         51.0     6120   Pave   NaN      Reg
#
#    LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 5          Lvl    AllPub  ...        0    NaN  MnPrv        Shed     700
# 10         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 15         Lvl    AllPub  ...        0    NaN  GdPrv         NaN       0
#
#    MoSold YrSold  SaleType  SaleCondition  SalePrice
# 5      10   2009        WD         Normal     143000
# 10      2   2008        WD         Normal     129500
# 15      7   2007        WD         Normal     132000
#
# [3 rows x 81 columns]

# %% [markdown]
# ### hse.loc[5:15]
# #use double brackets for single rows
# #use single brackets for double rows

# %%
hse.loc[(5,10,15),('Id','Street','SalePrice')]
# Out:
#     Id Street  SalePrice
# 5    6   Pave     143000
# 10  11   Pave     129500
# 15  16   Pave     132000

# %%
train.loc[(10,60,70,99),('PassengerId','Survived','Pclass','Name','Sex','Age','SibSp','Parch')]
# Out:
#     PassengerId  Survived  Pclass                             Name     Sex  \
# 10           11         1       3  Sandstrom, Miss. Marguerite Rut  female
# 60           61         0       3            Sirayanian, Mr. Orsen    male
# 70           71         0       2       Jenkin, Mr. Stephen Curnow    male
# 99          100         0       2                Kantor, Mr. Sinai    male
#
#      Age  SibSp  Parch
# 10   4.0      1      1
# 60  22.0      0      0
# 70  32.0      0      0
# 99  34.0      1      0

# %%
train.iloc[[10]]
# Out:
#     PassengerId  Survived  Pclass                             Name     Sex  \
# 10           11         1       3  Sandstrom, Miss. Marguerite Rut  female
#
#     Age  SibSp  Parch   Ticket  Fare Cabin Embarked
# 10  4.0      1      1  PP 9549  16.7    G6        S

# %%
train.iloc[10:14]
# Out:
#     PassengerId  Survived  Pclass                             Name     Sex  \
# 10           11         1       3  Sandstrom, Miss. Marguerite Rut  female
# 11           12         1       1         Bonnell, Miss. Elizabeth  female
# 12           13         0       3   Saundercock, Mr. William Henry    male
# 13           14         0       3      Andersson, Mr. Anders Johan    male
#
#      Age  SibSp  Parch     Ticket    Fare Cabin Embarked
# 10   4.0      1      1    PP 9549  16.700    G6        S
# 11  58.0      0      0     113783  26.550  C103        S
# 12  20.0      0      0  A/5. 2151   8.050   NaN        S
# 13  39.0      1      5     347082  31.275   NaN        S

# %%
train.iloc[1:5,0:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male

# %%
train.iloc[10,3]
# Out:
# 'Sandstrom, Miss. Marguerite Rut'

# %%
train.iloc[[10,11],[5,11]]
# Out:
#      Age Embarked
# 10   4.0        S
# 11  58.0        S

# %% [markdown]
# # Filter, sort and group by

# %%
train.iloc[0:5,[3]]
# Out:
#                                                 Name
# 0                            Braund, Mr. Owen Harris
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                             Heikkinen, Miss. Laina
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                           Allen, Mr. William Henry

# %%
train[train['Age']==80]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#       Sex   Age  SibSp  Parch Ticket  Fare Cabin Embarked
# 630  male  80.0      0      0  27042  30.0   A23        S

# %%
train[train['Age']>30]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 11            12         1       1
# ..           ...       ...     ...
# 873          874         0       3
# 879          880         1       1
# 881          882         0       3
# 885          886         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train[train['Age']<18]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 9             10         1       2      Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1       3          Sandstrom, Miss. Marguerite Rut
# 14            15         0       3     Vestrom, Miss. Hulda Amanda Adolfina
# 16            17         0       3                     Rice, Master. Eugene
# ..           ...       ...     ...                                      ...
# 850          851         0       3  Andersson, Master. Sigvard Harald Elias
# 852          853         0       3                  Boulos, Miss. Nourelain
# 853          854         1       1                Lines, Miss. Mary Conover
# 869          870         1       3          Johnson, Master. Harold Theodor
# 875          876         1       3         Najib, Miss. Adele Kiamie "Jane"
#
# ...

# %%
train[train['Sex']=="female"]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
train[(train['Age']>40)&(train['Sex']=="female")]
# Out:
#      PassengerId  Survived  Pclass  \
# 11            12         1       1
# 15            16         1       2
# 52            53         1       1
# 132          133         0       3
# 167          168         0       3
# 177          178         0       1
# 194          195         1       1
# 195          196         1       1
# 254          255         0       3
# 259          260         1       2
# 268          269         1       1
# 272          273         1       2
# 275          276         1       1
# 276          277         0       3
# 299          300         1       1
# 337          338         1       1
# 362          363         0       3
# 366          367         1       1
# 380          381         1       1
# 432          433         1       2
# 440          441         1       2
# 458          459         1       2
# 483          484         1       3
# 496          497         1       1
# 513          514         1       1
# ...

# %%
train[(train['Age']>60)& (train['Survived']==0)]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 33            34         0       2           Wheadon, Mr. Edward H  male
# 54            55         0       1  Ostby, Mr. Engelhart Cornelius  male
# 96            97         0       1       Goldschmidt, Mr. George B  male
# 116          117         0       3            Connors, Mr. Patrick  male
# 170          171         0       1       Van der hoef, Mr. Wyckoff  male
# 252          253         0       1       Stead, Mr. William Thomas  male
# 280          281         0       3                Duane, Mr. Frank  male
# 326          327         0       3       Nysveen, Mr. Johan Hansen  male
# 438          439         0       1               Fortune, Mr. Mark  male
# 456          457         0       1       Millet, Mr. Francis Davis  male
# 493          494         0       1         Artagaveytia, Mr. Ramon  male
# 545          546         0       1    Nicholson, Mr. Arthur Ernest  male
# ...

# %%
men= train[(train['Survived']==0)&(train['Sex']=="male")]
men['PassengerId'].count()
# Out:
# 468

# %%
ladies= train[(train['Survived']==0)&(train['Sex']=="female")]
ladies['PassengerId'].count()
# Out:
# 81

# %% [markdown]
# # Group by

# %%
train.groupby('Sex')['Age'].mean()
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
train.groupby(train['Survived']==1)['Age'].mean()
#avg age of survivors
# Out:
# Survived
# False    30.626179
# True     28.343690
# Name: Age, dtype: float64

# %%
train[(train['Survived']==1)]['Age'].mean()
# Out:
# 28.343689655172415

# %%
train.groupby('Survived')['Age'].min()
#youngest person that died
# Out:
# Survived
# 0    1.00
# 1    0.42
# Name: Age, dtype: float64

# %%
import numpy as np
exam_data = {'name': ['Kamau', 'Obama', 'Akoko', 'Waridi', 'Kobe', 'Neema','Michael', 'Laura', 'Kevin', 'Jonas'],'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
exam_data
# Out:
# {'name': ['Kamau',
#   'Obama',
#   'Akoko',
#   'Waridi',
#   'Kobe',
#   'Neema',
#   'Michael',
#   'Laura',
#   'Kevin',
#   'Jonas'],
#  'score': [12.5, 9, 16.5, nan, 9, 20, 14.5, nan, 8, 19],
#  'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
#  'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}

# %%
import pandas as pd
exam_df= pd.DataFrame(exam_data,index=labels)
exam_df
# Out:
#       name  score  attempts qualify
# a    Kamau   12.5         1     yes
# b    Obama    9.0         3      no
# c    Akoko   16.5         2     yes
# d   Waridi    NaN         3      no
# e     Kobe    9.0         2      no
# f    Neema   20.0         3     yes
# g  Michael   14.5         1     yes
# h    Laura    NaN         1      no
# i    Kevin    8.0         2      no
# j    Jonas   19.0         1     yes

# %%
exam_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, a to j
# Data columns (total 5 columns):
# name             10 non-null object
# score            9 non-null float64
# attempts         10 non-null int64
# qualify          10 non-null object
# attempts_rate    10 non-null float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 800.0+ bytes

# %%
exam_df.head(3)
# Out:
#     name  score  attempts qualify
# a  Kamau   12.5         1     yes
# b  Obama    9.0         3      no
# c  Akoko   16.5         2     yes

# %%
exam_df.iloc[:,0:2]
exam_df[['name','score']]
# Out:
#       name  score
# a    Kamau   12.5
# b    Obama    9.0
# c    Akoko   16.5
# d   Waridi   11.5
# e     Kobe    9.0
# f    Neema   20.0
# g  Michael   14.5
# h    Laura    NaN
# i    Kevin    8.0
# j    Jonas   19.0

# %%
exam_df[(exam_df['attempts']>2)]
# Out:
#      name  score  attempts qualify
# b   Obama    9.0         3      no
# d  Waridi    NaN         3      no
# f   Neema   20.0         3     yes

# %%
exam_df[(exam_df['score'].isnull())]
# Out:
#      name  score  attempts qualify
# d  Waridi    NaN         3      no
# h   Laura    NaN         1      no

# %%
exam_df.loc[['d'],['score']]=11.5
exam_df
# Out:
#       name  score  attempts qualify
# a    Kamau   12.5         1     yes
# b    Obama    9.0         3      no
# c    Akoko   16.5         2     yes
# d   Waridi   11.5         3      no
# e     Kobe    9.0         2      no
# f    Neema   20.0         3     yes
# g  Michael   14.5         1     yes
# h    Laura    NaN         1      no
# i    Kevin    8.0         2      no
# j    Jonas   19.0         1     yes

# %%
exam_df[(exam_df['score']>=15) & (exam_df['score']<=20)]
exam_df[(exam_df['score'].between(15,20))]
# Out:
#     name  score  attempts qualify  attempts_rate
# c  Akoko   16.5         2     yes       0.666667
# f  Neema   20.0         3     yes       1.000000
# j  Jonas   19.0         1     yes       0.333333

# %% [markdown]
# # joins
# pd.merge(df1,df2, on='left', how='inner')

# %%
exam_df[(exam_df['attempts']<2)&(exam_df['score']>15)]
# Out:
#     name  score  attempts qualify
# j  Jonas   19.0         1     yes

# %%
exam_df['attempts'].sum()
# Out:
# 19

# %%
exam_df['score'].mean()
# Out:
# 13.333333333333334

# %%
exam_df.drop('j')
# Out:
#       name  score  attempts qualify
# a    Kamau   12.5         1     yes
# b    Obama    9.0         3      no
# c    Akoko   16.5         2     yes
# d   Waridi   11.5         3      no
# e     Kobe    9.0         2      no
# f    Neema   20.0         3     yes
# g  Michael   14.5         1     yes
# h    Laura    NaN         1      no
# i    Kevin    8.0         2      no

# %%
exam_df.sort_values(['name','score'],ascending=(False,True))
exam_df.sort_values(by=['name','score'], ascending=(False,True))
# Out:
#       name  score  attempts qualify  attempts_rate
# d   Waridi   11.5         3      no       1.000000
# b    Obama    9.0         3      no       1.000000
# f    Neema   20.0         3     yes       1.000000
# g  Michael   14.5         1     yes       0.333333
# h    Laura    NaN         1      no       0.333333
# e     Kobe    9.0         2      no       0.666667
# i    Kevin    8.0         2      no       0.666667
# a    Kamau   12.5         1     yes       0.333333
# j    Jonas   19.0         1     yes       0.333333
# c    Akoko   16.5         2     yes       0.666667

# %%
exam_df['attempts_rate']= (exam_df['attempts']/exam_df['attempts'].max())*100
exam_df
# Out:
#       name  score  attempts qualify  attempts_rate
# a    Kamau   12.5         1     yes      33.333333
# b    Obama    9.0         3      no     100.000000
# c    Akoko   16.5         2     yes      66.666667
# d   Waridi   11.5         3      no     100.000000
# e     Kobe    9.0         2      no      66.666667
# f    Neema   20.0         3     yes     100.000000
# g  Michael   14.5         1     yes      33.333333
# h    Laura    NaN         1      no      33.333333
# i    Kevin    8.0         2      no      66.666667
# j    Jonas   19.0         1     yes      33.333333

# %%
exam_df.fillna(exam_df['score'].mean())
# Out:
#       name      score  attempts qualify  attempts_rate
# a    Kamau  12.500000         1     yes       0.333333
# b    Obama   9.000000         3      no       1.000000
# c    Akoko  16.500000         2     yes       0.666667
# d   Waridi  11.500000         3      no       1.000000
# e     Kobe   9.000000         2      no       0.666667
# f    Neema  20.000000         3     yes       1.000000
# g  Michael  14.500000         1     yes       0.333333
# h    Laura  13.333333         1      no       0.333333
# i    Kevin   8.000000         2      no       0.666667
# j    Jonas  19.000000         1     yes       0.333333

# %%
exam_df.groupby('attempts')['attempts'].count()
# Out:
# attempts
# 1    4
# 2    3
# 3    3
# Name: attempts, dtype: int64
